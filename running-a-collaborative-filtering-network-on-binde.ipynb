# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# The first step to getting your notebook working on Binder is to export the learner you have created

# %%
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
learn_inf = load_learner('export.pkl')

# %%
def get_rating(learn, user):
    with torch.no_grad():
        movies = torch.arange(learn.model.i_weight.num_embeddings)
        users = tensor([user])
        try:
            dot = learn.u_weight(users).unsqueeze(1) * learn.i_weight(movies)
            res = dot.sum(-1) + learn.u_bias(users) + learn.i_bias(movies).squeeze()
            return (torch.sigmoid(res) * (learn.y_range[1]-learn.y_range[0]) + learn.y_range[0])[0]
        except:
            print('User not recognized')

# %%
itemNameText = widgets.Text(
    value='',
    placeholder='What is the number of the item?',
    description='String:',
    disabled=False   
)

# %%
userNameText = widgets.Text(
    value='',
    placeholder='What user number?',
    description='String:',
    disabled=False   
)

# %%
outputText = widgets.Text(
    value='',
    placeholder='Output',
    description='String:',
    disabled=False   
)

# %%
btn_run = widgets.Button(description='Make Prediction')

# %%
def get_rating(learn, user):
    if type(user) == str:
        user = usernameToUserID[usernameToUserID['Username'] == 'OurUser']['UserID'][0].item()
    with torch.no_grad():
        games = torch.arange(learn.model.i_weight.num_embeddings)
        users = tensor([user])
        try:
            dot = learn.u_weight(users).unsqueeze(1) * learn.i_weight(games)
            res = dot.sum(-1) + learn.u_bias(users) + learn.i_bias(games).squeeze()
            return (torch.sigmoid(res) * (learn.y_range[1]-learn.y_range[0]) + learn.y_range[0])[0]
        except:
            print('User not recognized')

# %%
list(dls.classes['original_title']).index("Singin' in the Rain")

# %%
def on_click_classify(change):
    outputText.clear_output()
    itemNum = int(itemNameText.value)
    userNum  = int(userNameText.value)
    predictions = get_rating(learn, userNum)
    index = predictions.argsort(descending=True)[:20]
    outputText.value = predictions[itemNum]

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Get your predicted rating!'), 
      itemNameText, userNameText, outputText, btn_run])
